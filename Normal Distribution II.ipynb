# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (8, 5)

# %%
#y_cdf = ss.norm.cdf(0.87,0,1)
#y_cdf2 = ss.norm.cdf(1.28,0,1)

# %%
x = np.linspace(-5,5,1000)
y_pdf = ss.norm.pdf(x,0,1)
#Lambda Alternative for the upper function
#l = np.linspace(-5,5,1000)
#z = lambda a: ss.norm.pdf(l,0,1)
plt.plot(x,y_cdf)
plt.plot(0.87,y_pdf87)
