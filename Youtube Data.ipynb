# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20,12)

# %%
data = pd.read_csv('Datasets/ytubesocialblade.csv')
data.shape
# Out:
# (5000, 6)

# %%
data.sort_values('Video Uploads',inplace = True)
video = data[:200]['Video Uploads']
subscribers = data[:200]['Subscribers']

# %%
plt.scatter(video,subscribers)
plt.show()
